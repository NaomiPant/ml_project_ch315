# %% [markdown]
# # ML for Gas Adsorption

# %% [markdown]
# ## -1. Only if you run this notebook on Colab

# %% [markdown]
# If you use this notebook on Colab, please uncomment the lines below (remove the `#`) and execute the cell.

# %%
#import sys
#!{sys.executable} -m pip install -U pandas-profiling[notebook]
#!jupyter nbextension enable --py widgetsnbextension
#!pip install --upgrade pandas sklearn holoviews bokeh plotly matplotlib
#!wget https://raw.githubusercontent.com/kjappelbaum/ml_molsim/2022/descriptornames.py
#!mkdir data
#!cd data && wget https://github.com/kjappelbaum/ml_molsim/raw/2022/data/data.csv
#!cd data && wget https://github.com/kjappelbaum/ml_molsim/raw/2022/data/features.csv
# import os, holoviews as hv
# os.environ['HV_DOC_HTML'] = 'true'

# %% [markdown]
# ## Import packages we will need

# %%
# basics
import os
import numpy as np
import pprint as pp

# pandas is used to read/process data
import pandas as pd

# machine learning dependencies
# scaling of data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
# train/test split
from sklearn.model_selection import train_test_split
# model selection
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
# the KRR model
from sklearn.kernel_ridge import KernelRidge
# linear model
from sklearn.linear_model import LinearRegression
# pipeline to streamline modeling pipelines
from sklearn.pipeline import Pipeline
# principal component analysis
from sklearn.decomposition import PCA
# polynomial kernel
from sklearn.metrics.pairwise import polynomial_kernel
# Dummy model as baseline
from sklearn.dummy import DummyClassifier, DummyRegressor
# Variance Threshold for feature selection
from sklearn.feature_selection import VarianceThreshold, SelectFromModel
# metrics to measure model performance
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             mean_absolute_error, mean_squared_error, max_error)

# save/load models
import joblib

# For the permutation importance implementation
from joblib import Parallel
from joblib import delayed
from sklearn.metrics import check_scoring
from sklearn.utils import Bunch
from sklearn.utils import check_random_state
from sklearn.utils import check_array

# plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from pymatviz.scatter import density_scatter_with_hist as hist_density

RANDOM_SEED = 4242424242
DATA_DIR = 'data'
DATA_FILE = os.path.join( 'data.csv')

np.random.seed(RANDOM_SEED)

# %%
other_descriptors = ["CellV [A^3]"]

geometric_descriptors = [
    "Di",
    "Df",
    "Dif",
    "density [g/cm^3]",
    "total_SA_volumetric",
    "total_SA_gravimetric",
    "total_POV_volumetric",
    "total_POV_gravimetric",
]

linker_descriptors = [
    "f-lig-chi-0",
    "f-lig-chi-1",
    "f-lig-chi-2",
    "f-lig-chi-3",
    "f-lig-Z-0",
    "f-lig-Z-1",
    "f-lig-Z-2",
    "f-lig-Z-3",
    "f-lig-I-0",
    "f-lig-I-1",
    "f-lig-I-2",
    "f-lig-I-3",
    "f-lig-T-0",
    "f-lig-T-1",
    "f-lig-T-2",
    "f-lig-T-3",
    "f-lig-S-0",
    "f-lig-S-1",
    "f-lig-S-2",
    "f-lig-S-3",
    "lc-chi-0-all",
    "lc-chi-1-all",
    "lc-chi-2-all",
    "lc-chi-3-all",
    "lc-Z-0-all",
    "lc-Z-1-all",
    "lc-Z-2-all",
    "lc-Z-3-all",
    "lc-I-0-all",
    "lc-I-1-all",
    "lc-I-2-all",
    "lc-I-3-all",
    "lc-T-0-all",
    "lc-T-1-all",
    "lc-T-2-all",
    "lc-T-3-all",
    "lc-S-0-all",
    "lc-S-1-all",
    "lc-S-2-all",
    "lc-S-3-all",
    "lc-alpha-0-all",
    "lc-alpha-1-all",
    "lc-alpha-2-all",
    "lc-alpha-3-all",
    "D_lc-chi-0-all",
    "D_lc-chi-1-all",
    "D_lc-chi-2-all",
    "D_lc-chi-3-all",
    "D_lc-Z-0-all",
    "D_lc-Z-1-all",
    "D_lc-Z-2-all",
    "D_lc-Z-3-all",
    "D_lc-I-0-all",
    "D_lc-I-1-all",
    "D_lc-I-2-all",
    "D_lc-I-3-all",
    "D_lc-T-0-all",
    "D_lc-T-1-all",
    "D_lc-T-2-all",
    "D_lc-T-3-all",
    "D_lc-S-0-all",
    "D_lc-S-1-all",
    "D_lc-S-2-all",
    "D_lc-S-3-all",
    "D_lc-alpha-0-all",
    "D_lc-alpha-1-all",
    "D_lc-alpha-2-all",
    "D_lc-alpha-3-all",
]

metalcenter_descriptors = [
    "mc_CRY-chi-0-all",
    "mc_CRY-chi-1-all",
    "mc_CRY-chi-2-all",
    "mc_CRY-chi-3-all",
    "mc_CRY-Z-0-all",
    "mc_CRY-Z-1-all",
    "mc_CRY-Z-2-all",
    "mc_CRY-Z-3-all",
    "mc_CRY-I-0-all",
    "mc_CRY-I-1-all",
    "mc_CRY-I-2-all",
    "mc_CRY-I-3-all",
    "mc_CRY-T-0-all",
    "mc_CRY-T-1-all",
    "mc_CRY-T-2-all",
    "mc_CRY-T-3-all",
    "mc_CRY-S-0-all",
    "mc_CRY-S-1-all",
    "mc_CRY-S-2-all",
    "mc_CRY-S-3-all",
    "D_mc_CRY-chi-0-all",
    "D_mc_CRY-chi-1-all",
    "D_mc_CRY-chi-2-all",
    "D_mc_CRY-chi-3-all",
    "D_mc_CRY-Z-0-all",
    "D_mc_CRY-Z-1-all",
    "D_mc_CRY-Z-2-all",
    "D_mc_CRY-Z-3-all",
    "D_mc_CRY-I-0-all",
    "D_mc_CRY-I-1-all",
    "D_mc_CRY-I-2-all",
    "D_mc_CRY-I-3-all",
    "D_mc_CRY-T-0-all",
    "D_mc_CRY-T-1-all",
    "D_mc_CRY-T-2-all",
    "D_mc_CRY-T-3-all",
    "D_mc_CRY-S-0-all",
    "D_mc_CRY-S-1-all",
    "D_mc_CRY-S-2-all",
    "D_mc_CRY-S-3-all",
]

functionalgroup_descriptors = [
    "func-chi-0-all",
    "func-chi-1-all",
    "func-chi-2-all",
    "func-chi-3-all",
    "func-Z-0-all",
    "func-Z-1-all",
    "func-Z-2-all",
    "func-Z-3-all",
    "func-I-0-all",
    "func-I-1-all",
    "func-I-2-all",
    "func-I-3-all",
    "func-T-0-all",
    "func-T-1-all",
    "func-T-2-all",
    "func-T-3-all",
    "func-S-0-all",
    "func-S-1-all",
    "func-S-2-all",
    "func-S-3-all",
    "func-alpha-0-all",
    "func-alpha-1-all",
    "func-alpha-2-all",
    "func-alpha-3-all",
    "D_func-chi-0-all",
    "D_func-chi-1-all",
    "D_func-chi-2-all",
    "D_func-chi-3-all",
    "D_func-Z-0-all",
    "D_func-Z-1-all",
    "D_func-Z-2-all",
    "D_func-Z-3-all",
    "D_func-I-0-all",
    "D_func-I-1-all",
    "D_func-I-2-all",
    "D_func-I-3-all",
    "D_func-T-0-all",
    "D_func-T-1-all",
    "D_func-T-2-all",
    "D_func-T-3-all",
    "D_func-S-0-all",
    "D_func-S-1-all",
    "D_func-S-2-all",
    "D_func-S-3-all",
    "D_func-alpha-0-all",
    "D_func-alpha-1-all",
    "D_func-alpha-2-all",
    "D_func-alpha-3-all",
]


summed_linker_descriptors = [
    "sum-f-lig-chi-0",
    "sum-f-lig-chi-1",
    "sum-f-lig-chi-2",
    "sum-f-lig-chi-3",
    "sum-f-lig-Z-0",
    "sum-f-lig-Z-1",
    "sum-f-lig-Z-2",
    "sum-f-lig-Z-3",
    "sum-f-lig-I-0",
    "sum-f-lig-I-1",
    "sum-f-lig-I-2",
    "sum-f-lig-I-3",
    "sum-f-lig-T-0",
    "sum-f-lig-T-1",
    "sum-f-lig-T-2",
    "sum-f-lig-T-3",
    "sum-f-lig-S-0",
    "sum-f-lig-S-1",
    "sum-f-lig-S-2",
    "sum-f-lig-S-3",
    "sum-lc-chi-0-all",
    "sum-lc-chi-1-all",
    "sum-lc-chi-2-all",
    "sum-lc-chi-3-all",
    "sum-lc-Z-0-all",
    "sum-lc-Z-1-all",
    "sum-lc-Z-2-all",
    "sum-lc-Z-3-all",
    "sum-lc-I-0-all",
    "sum-lc-I-1-all",
    "sum-lc-I-2-all",
    "sum-lc-I-3-all",
    "sum-lc-T-0-all",
    "sum-lc-T-1-all",
    "sum-lc-T-2-all",
    "sum-lc-T-3-all",
    "sum-lc-S-0-all",
    "sum-lc-S-1-all",
    "sum-lc-S-2-all",
    "sum-lc-S-3-all",
    "sum-lc-alpha-0-all",
    "sum-lc-alpha-1-all",
    "sum-lc-alpha-2-all",
    "sum-lc-alpha-3-all",
    "sum-D_lc-chi-0-all",
    "sum-D_lc-chi-1-all",
    "sum-D_lc-chi-2-all",
    "sum-D_lc-chi-3-all",
    "sum-D_lc-Z-0-all",
    "sum-D_lc-Z-1-all",
    "sum-D_lc-Z-2-all",
    "sum-D_lc-Z-3-all",
    "sum-D_lc-I-0-all",
    "sum-D_lc-I-1-all",
    "sum-D_lc-I-2-all",
    "sum-D_lc-I-3-all",
    "sum-D_lc-T-0-all",
    "sum-D_lc-T-1-all",
    "sum-D_lc-T-2-all",
    "sum-D_lc-T-3-all",
    "sum-D_lc-S-0-all",
    "sum-D_lc-S-1-all",
    "sum-D_lc-S-2-all",
    "sum-D_lc-S-3-all",
    "sum-D_lc-alpha-0-all",
    "sum-D_lc-alpha-1-all",
    "sum-D_lc-alpha-2-all",
    "sum-D_lc-alpha-3-all",
]

summed_metalcenter_descriptors = [
    "sum-mc_CRY-chi-0-all",
    "sum-mc_CRY-chi-1-all",
    "sum-mc_CRY-chi-2-all",
    "sum-mc_CRY-chi-3-all",
    "sum-mc_CRY-Z-0-all",
    "sum-mc_CRY-Z-1-all",
    "sum-mc_CRY-Z-2-all",
    "sum-mc_CRY-Z-3-all",
    "sum-mc_CRY-I-0-all",
    "sum-mc_CRY-I-1-all",
    "sum-mc_CRY-I-2-all",
    "sum-mc_CRY-I-3-all",
    "sum-mc_CRY-T-0-all",
    "sum-mc_CRY-T-1-all",
    "sum-mc_CRY-T-2-all",
    "sum-mc_CRY-T-3-all",
    "sum-mc_CRY-S-0-all",
    "sum-mc_CRY-S-1-all",
    "sum-mc_CRY-S-2-all",
    "sum-mc_CRY-S-3-all",
    "sum-D_mc_CRY-chi-0-all",
    "sum-D_mc_CRY-chi-1-all",
    "sum-D_mc_CRY-chi-2-all",
    "sum-D_mc_CRY-chi-3-all",
    "sum-D_mc_CRY-Z-0-all",
    "sum-D_mc_CRY-Z-1-all",
    "sum-D_mc_CRY-Z-2-all",
    "sum-D_mc_CRY-Z-3-all",
    "sum-D_mc_CRY-I-0-all",
    "sum-D_mc_CRY-I-1-all",
    "sum-D_mc_CRY-I-2-all",
    "sum-D_mc_CRY-I-3-all",
    "sum-D_mc_CRY-T-0-all",
    "sum-D_mc_CRY-T-1-all",
    "sum-D_mc_CRY-T-2-all",
    "sum-D_mc_CRY-T-3-all",
    "sum-D_mc_CRY-S-0-all",
    "sum-D_mc_CRY-S-1-all",
    "sum-D_mc_CRY-S-2-all",
    "sum-D_mc_CRY-S-3-all",
]

summed_functionalgroup_descriptors = [
    "sum-func-chi-0-all",
    "sum-func-chi-1-all",
    "sum-func-chi-2-all",
    "sum-func-chi-3-all",
    "sum-func-Z-0-all",
    "sum-func-Z-1-all",
    "sum-func-Z-2-all",
    "sum-func-Z-3-all",
    "sum-func-I-0-all",
    "sum-func-I-1-all",
    "sum-func-I-2-all",
    "sum-func-I-3-all",
    "sum-func-T-0-all",
    "sum-func-T-1-all",
    "sum-func-T-2-all",
    "sum-func-T-3-all",
    "sum-func-S-0-all",
    "sum-func-S-1-all",
    "sum-func-S-2-all",
    "sum-func-S-3-all",
    "sum-func-alpha-0-all",
    "sum-func-alpha-1-all",
    "sum-func-alpha-2-all",
    "sum-func-alpha-3-all",
    "sum-D_func-chi-0-all",
    "sum-D_func-chi-1-all",
    "sum-D_func-chi-2-all",
    "sum-D_func-chi-3-all",
    "sum-D_func-Z-0-all",
    "sum-D_func-Z-1-all",
    "sum-D_func-Z-2-all",
    "sum-D_func-Z-3-all",
    "sum-D_func-I-0-all",
    "sum-D_func-I-1-all",
    "sum-D_func-I-2-all",
    "sum-D_func-I-3-all",
    "sum-D_func-T-0-all",
    "sum-D_func-T-1-all",
    "sum-D_func-T-2-all",
    "sum-D_func-T-3-all",
    "sum-D_func-S-0-all",
    "sum-D_func-S-1-all",
    "sum-D_func-S-2-all",
    "sum-D_func-S-3-all",
    "sum-D_func-alpha-0-all",
    "sum-D_func-alpha-1-all",
    "sum-D_func-alpha-2-all",
    "sum-D_func-alpha-3-all",
]

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short question}}$
# - We declared a global variable to fix the random seed (`RANDOM_SEED`). Why did we do this?

# %% [markdown]
# We fix the random seed with a global variable so that the same set of random numbers are generated every run. This ensures that the results are reproducible and repeatable.

# %% [markdown]
# ## Hands-on Project: Carbon-dioxide uptake in MOFs

# %% [markdown]
# In this exercise we will build a model that can predict the CO$_2$ uptake of metal-organic frameworks (MOFs), which are crystalline materials consisting of inorganic metal nodes linked by organic linkers.
#
# ![MOF building principle](assets/mof_building_principle.png)
#
# There are two main **learning goals** for this exercise:
#
# 1. Understand the typical workflow for machine learning in materials science. We will cover exploratory data analysis (EDA) and supervised learning (KRR).
#
# 2. Get familiar with some Python packages that are useful for data analysis and visualization.
#
# At the end of the exercise, you will produce an interactive plot like the one below, comparing the predictions of your model against CO$_2$ computed with GCMC simulations.
# The histograms show the distributions of the errors on the training set (left) and on the test set (right).
#
#
#
# <img src="assets/result.gif" alt="Parity interactive" width="700"/>
#
# This exercise requires a basic knowledge of Python, e.g. that you can write list comprehensions, and are able to read documentation of functions provided by Python packages.
# You will be asked to provide some function arguments (indicated by `#fillme` comments).
#
# You can execute all the following code cells by pressing SHIFT and ENTER and get informations about the functions by pressing TAB when you are between the parentheses (see the notes for more tips).
#
# Also the [sklearn documentation](https://scikit-learn.org/stable/user_guide.html) is a great source of reference with many explanations and examples.
#
# In pandas dataframe (df) you can select columns using their name by running `df[columnname]`. If at any point you think that the dataset is too large for your computer, you can select a subset using `df.sample()` or by making the test set larger in the train/test split (section 2).

# %% [markdown]
# ## 1. Import the data

# %%
df = pd.read_csv(DATA_FILE)

# %% [markdown]
# Let's take a look at the first few rows to see if everythings seems reasonable ...

# %%
df.head()
# Out:
#    ASA [m^2/cm^3]  CellV [A^3]       Df       Di      Dif  NASA [m^2/cm^3]  \
# 0         2329.01      1251.28  6.61256  8.87694  8.48668              0.0
# 1         1983.81      1254.01  5.80566  7.13426  7.13154              0.0
# 2         2259.13      1250.58  5.99131  8.01682  7.98933              0.0
# 3         1424.54      1249.27  4.73477  7.05822  7.05822              0.0
# 4         2228.31      1250.61  6.40783  8.35944  8.26946              0.0
#
#    POAV [cm^3/g]    POAVF  PONAV [cm^3/g]  PONAVF  ...  pure_methane_widomHOA  \
# 0       0.818919  0.68874             0.0     0.0  ...              -8.144317
# 1       0.495493  0.58032             0.0     0.0  ...             -10.208005
# 2       0.728036  0.65710             0.0     0.0  ...              -8.479801
# 3       0.453157  0.47338             0.0     0.0  ...             -12.615382
# 4       0.700539  0.65092             0.0     0.0  ...              -8.743404
#
#   pure_uptake_CO2_298.00_15000  pure_uptake_CO2_298.00_1600000  \
# 0                     0.111981                       14.218595
# 1                     0.481625                        9.312424
# 2                     0.401683                       14.796071
# 3                     0.821747                       10.816880
# 4                     0.258905                       14.153999
#
#    pure_uptake_methane_298.00_580000  pure_uptake_methane_298.00_6500000  \
# 0                           1.680640                            9.163066
# 1                           1.513152                            5.908356
# 2                           1.569714                            7.933198
# 3                           2.161833                            6.710778
# 4                           1.653013                            8.272621
#
#    logKH_CO2  logKH_CH4       CH4DC    CH4HPSTP   CH4LPSTP
# 0  -5.125451  -5.511444  175.569974  215.005044  39.435070
# 1  -4.502967  -5.505947  143.616349  193.059644  49.443295
# 2  -4.433968  -5.525707  160.238808  199.765744  39.526937
# 3  -4.135434  -5.297082  132.576623  195.582107  63.005483
# 4  -4.774301  -5.515219  171.601539  214.452966  42.851427
#
# [5 rows x 343 columns]

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for a hint</font></summary>
# <ul>
#     <li>Use something like <code>pd.options.display.max_columns=100</code> to adjust how many columns are shown.<code>pd.options.display.max_columns=100</code>  would show at maximum 100 columns. </li>
# </ul>
# </details>

# %% [markdown]
# Let's also get some basic information ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Columns: 343 entries, ASA [m^2/cm^3] to CH4LPSTP
# dtypes: float64(342), object(1)
# memory usage: 45.5+ MB

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short question}}$
# - How many materials are in the dataset?
# - Which datatypes do we deal with?

# %% [markdown]
# According to the table, 5 materials are in the dataset corresponding to 5 rows. <br>
# The datatypes dealt with are float.

# %% [markdown]
# Below, we define three global variables (hence upper case), which are the *names* of our feature and target columns. We will use the `TARGET` for the actual regression and the `TARGET_BINARY` only for the stratified train/test split. The `FEATURES` variable is a list of column names of our dataframe.

# %%
TARGET = "pure_uptake_CO2_298.00_1600000"
TARGET_BINARY = "target_binned"  # will be created later
FEATURES = (
    geometric_descriptors
    + summed_functionalgroup_descriptors
    + summed_linker_descriptors
    + summed_metalcenter_descriptors
)

# %% [markdown]
# As descriptors we will use geometric properties such as density, pore volume, etc. and [revised autocorrelation functions](https://pubs.acs.org/doi/abs/10.1021/acs.jpca.7b08750) (RACs) that have been optimized for describing inorganic compounds ([and recently adapated for MOFs](https://www.nature.com/articles/s41467-020-17755-8))

# %% [markdown]
# Examples for pore geometry descriptors (in `geometric_descriptors`) include: $D_i$ (the size of the largest included sphere), $D_f$ (the largest free sphere), and $D_{if}$ (the largest included free sphere) along the pore $-$ three ways of characterizing pore size.
#
# ![pore diameters](assets/spheres.png)
#
# Also included are the surface area (SA) of the pore, and the probe-occupiable pore volume (POV).
# More details on the description of pore geometries can be found in [Ongari et al.](https://pubs.acs.org/doi/abs/10.1021/acs.langmuir.7b01682)

# %% [markdown]
# RACs (in the lists starting with `summed_...`) operate on the structure graph and encode information about the metal center, linkers and the functional groups as differences or products of heuristics that are relevant for inorganic chemistry, such as electronegativity ($\chi$), connectivity ($T$), identity ($I$), covalent radii ($S$), and nuclear charge ($Z$).

# %% [markdown]
# <img src="assets/racs.png" alt="RACs scheme from the lecture" width="700"/>

# %% [markdown]
# The number in the descriptornames shows the coordination shell that was considered in the calculation of the RACs.

# %% [markdown]
# The target we use for this application is the high-pressure CO$_2$ uptake. This is the amount of CO$_2$ (mmol) the MOF can load per gram.

# %% [markdown]
# ## 2. Split the data

# %% [markdown]
# Next, we split our data into a training set and a test set.
#
# In order to prevent *any* information of the test set from leaking into our model, we split *before* starting to analyze or transform our data. For more details on why this matters, see [chapter 7.10.2 of Elements of Statistical Learning](https://web.stanford.edu/~hastie/ElemStatLearn//printings/ESLII_print10.pdf).

# %% [markdown]
# ### 2.1. Split with stratification

# %% [markdown]
# [Stratification](https://en.wikipedia.org/wiki/Stratified_sampling) ensures that the class distributions (ratio of "good" to "bad" materials) are the same in the training and test set.
#
#  $\color{DarkBlue}{\textsf{Short question}}$
#
# - Why is this important? What could happen if we would not do this?
#
#
# For stratification to work, we to define what makes a "good" or a "bad" material. We will use 15 mmol CO$_2$ / g as the threshold for the uptake, thus binarizing our continuous target variable. (You can choose it based on the histogram of the variables).

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
#  - add a column 'target_binary' that encodes whether a material is low performing (`0`) or high perfoming (`1`) by comparing the uptake with the `THRESHOLD`

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for a hint</font></summary>
# <ul>
#     <li> you can use <a href='https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html'>pd.cut</a>,
#     <a href='https://stackoverflow.com/questions/4406389/if-else-in-a-list-comprehension'>list comprehension</a>, the <a href='https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.Binarizer.html#sklearn.preprocessing.Binarizer'> binarizer in sklearn </a>...) </li>
#     <li> a list comprehension example: <code> [1 if value > THRESHOLD else 0 for value in df[TARGET]] </code> </li>
# </ul>
# </details>

# %%
THRESHOLD = 15 # in units of mmol CO2/g
df[TARGET_BINARY] = (df['pure_uptake_CO2_298.00_1600000'] > THRESHOLD).astype(int)

# %% [markdown]
# Now, we can perform the actual split into training and test set.

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - select reasonable values for `XX` and `XY` and then perform the test/train splits. What do you consider when making this decision (think about what you would do with really small and really big datasets, what happens if you have only one test point, what happens to the model performance if you have more test points than training points)?
# - why do we need to perform the split into a training and test set?
# - would we use the test set to tune the hyperparameters of our model?
#
# <details>
# <summary> <font color='green'>Click here for a hint</font></summary>
# <ul>
#     <li>The `size` arguments can either be integers or, often more convenient, decimals like 0.1</li>
#     <li>When you perform the split into training and test set you need to trade-off bias (pessimistic bias due to little training data) and variance (due to little test data) </li>
#     <li>A typical split cloud be 70/30, but for huge dataset the test set might be too big and for small datasets the training set might be too small in this way </li>
# </ul>
# </details>

# %% [markdown]
# - What do you consider when making this decision (think about what you would do with really small and really big datasets, what happens if you have only one test point, what happens to the model performance if you have more test points than training points)?
#
# We need to consider the size of our dataset. If the dataset is small, it will need 70 to 80% to train. But if the dataset is big, 10 to 20% to train is enough. If we have only one test point, the test result would be completely random and not very representative. If we have more test points than training points, the model learns from very little data.
#
# - why do we need to perform the split into a training and test set?
#
# To evaluate the model's ability to generalize on new data. Because if we test the model on the same data that were used for training, the model already know the answers so this is not representative of its performance.
#
# - would we use the test set to tune the hyperparameters of our model?
#
# No, because if he used the test set, it would be like giving the answers to the model.

# %%
df_train_stratified, df_test_stratified = train_test_split(
    df,
    train_size=0.7,
    test_size=0.3,
    random_state=RANDOM_SEED,
    stratify=df[TARGET_BINARY],
)

# %% [markdown]
# ## 3. Exploratory data analysis (EDA)

# %% [markdown]
# After we have put the test set aside, we can give the training set a closer look.

# %% [markdown]
# ### 3.1. Correlations

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - Plot some features against the target property and calculate the Pearson and Spearman correlation coefficient (what is the different between those correlation coefficients?)
# - What are the strongest correlations? Did you expect them?
# - What can be a problem when features are correlated?
# - *Optional:* Do they change if you switch from CO$_2$ to CH$_4$ uptake as the target instead? Explain your observation.

# %% [markdown]
# To get the correlation matrices, you can use the `df.corr(method=)`method on your dataframe (`df`). You might want to calculate not the full correlation matrix but just the correlation of the features with the targets

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for a hint</font></summary>
# <ul>
#     <li> To get the correlation with a target, you can use indexing. E.g. <code>df.corr(method='spearman')[TARGET]</code></li>
#     <li> use <code>.sort_values()</code> method on the output of `df.corr()` to sort by the value of the correlation coefficient  </li>
#       <li> You can use something like <code>scatter = hv.Scatter(df, 'Di', [TARGET,  'density [g/cm^3]']).opts(color='density [g/cm^3]', cmap='rainbow')</code> for plotting. Also consider the <a href="https://holoviews.org/reference/elements/matplotlib/Scatter.html"> <code>holoviews</code> documentation</a>. In case <code>holoviews</code> is too new for you, you can of course just use <code>matplotlib</code> and something like <code>plt.scatter(x,y)</code> </li>
# </ul>
# </details>

# %%
#Plot some features against the target property
# Choose some features (first 6 features)
selected_features = FEATURES[:6]

for feat in selected_features:
    plt.figure(figsize=(8,6))
    plt.scatter(df[feat], df[TARGET], alpha=0.6)
    plt.xlabel(feat)
    plt.ylabel(TARGET)
    plt.title(f"{feat} vs {TARGET}")
    plt.grid(True)
    plt.show()

#calculate Pearson and Spearman correlation coefficient
pearson_corr = df[FEATURES + [TARGET]].corr(method='pearson')[TARGET].sort_values(ascending=False)
print("Top features by Pearson correlation:")
print(pearson_corr.head(10))

spearman_corr = df[FEATURES + [TARGET]].corr(method='spearman')[TARGET].sort_values(ascending=False)
print("\nTop features by Spearman correlation:")
print(spearman_corr.head(10))
# Out:
# Top features by Pearson correlation:
# pure_uptake_CO2_298.00_1600000    1.000000
# total_SA_gravimetric              0.925695
# total_POV_volumetric              0.916252
# total_SA_volumetric               0.847655
# total_POV_gravimetric             0.776961
# Df                                0.766362
# Dif                               0.758502
# Di                                0.758448
# sum-D_lc-chi-2-all                0.157190
# sum-mc_CRY-chi-0-all              0.150381
# Name: pure_uptake_CO2_298.00_1600000, dtype: float64
#
# Top features by Spearman correlation:
# pure_uptake_CO2_298.00_1600000    1.000000
# total_POV_gravimetric             0.956879
# total_SA_gravimetric              0.953690
# total_POV_volumetric              0.940159
# total_SA_volumetric               0.882437
# Di                                0.848383
# Dif                               0.848379
# Df                                0.844439
# sum-D_mc_CRY-chi-1-all            0.190494
# sum-D_lc-chi-2-all                0.179045
# Name: pure_uptake_CO2_298.00_1600000, dtype: float64

# %% [markdown]
# #### - What is the different between those correlation coefficients?
# Pearson and Spearman correlations both measure the strength and direction of a relationship between some features and the target, but they differ in their assumptions and what they measure.
# Peason correlation measures the linear relationship. Spearman correlation measures the monotopic relationship (it's more flexible).
#
# #### - What are the strongest correlations? Did you expect them?
# The strongest correlations are the total surface area (SA) and the total pore volume(POV) gravimetric or volumetrc. Only the order of the strongest are different for Pearson and Spearman.
# Yes, because SA and POV are strongly correlated with the CO2 uptake. Indeed, with a larger surface area or pore volume there is more space for CO2 adsorption (a higher CO2 uptake).
#
# #### - What can be a problem when features are correlated?
# If two features are highly correlated, the model could view them as interchangeable. Especially if the model is linear, this makes the model overfit over one feature without taking into acount the other features causing it to miss the mark while testing as it is only following one feature.
#
# #### - *Optional:* Do they change if you switch from CO$_2$ to CH$_4$ uptake as the target instead? Explain your observation.

# %% [markdown]
# ## 4. Baselines

# %% [markdown]
# For machine learning, it is important to have some *baselines* to which one then compares the results of a model. Think of a classification model for some rare disease where we only have 1% postives. A classification model that only predictes the negatives *all the time* will still have a amazingly high accuracy. To be able to understand if our model is really better than such a simple prediction we need to make the simple prediction first. This is what we call a baseline.
#
# A baseline could be a really simple model, a basic heuristic or the current state of the art.
# this. We will use a heuristic.
#
# For this we use sklearn `Dummy` objects that simply calculate the mean, the median or the most frequent case of the training set, when you run the `fit()` method on them (which takes the features matrix $\mathbf{X}$ and the labels $\mathbf{y}$ as arguments.
# This is, the prediction of a `DummyRegressor` with `mean` strategy will always be the mean, independent of the input (it will not look at the feature matrix!).
#
# Instead of using those `sklearn` objects you could also just manually compute the the mean or median of the dataset. But we will use those objects as we can learn in this way how to use estimators in `sklearn` and it is also allows you to test your full pipeline with different (baseline) models.
# What does this mean? In practice this means that you can use all the regression and classification models shown in the figure below in the same way, they will all have a `fit()` method that accepts `X` and `y` and a predict method that accepts `X` and returns the predictions.
#
#
# <img src="https://scikit-learn.org/stable/assets/ml_map.png" alt="ML Map" width="800"/>
#
# The estimator objects can be always used in the same way
#
# <img src="https://static.packt-cdn.com/products/9781789800265/graphics/d49a2e95-8f22-42ed-89f1-474b3d028787.png" alt="ML Map" width="400"/>
#
# Using these objects, instead of the mean directly, allows you to easily swap them with other models in pipelines, where one chains many data transformation steps (see section 6).

# %% [markdown]
# ### 4.1. Build dummy models

# %% [markdown]
# $\color{DarkBlue}{\textsf{Short Question}}$
# - If you call `.fit(X, y)` on a `DummyRegressor` does it actually use the `X`? If not, why is there still the place for the `X` in the function? If yes, how does it use it? <br>
#
# The DummyRegressor does not actually use the X feature matrix, but only the target matrix y. There is still the place for X in the function so that all scikit-learn models are named in the same manner. This enables to switch between models (for example, switch between DummyRegressor and LinearRegression) more easily and reuse the same code.
#
# $\color{DarkBlue}{\textsf{Short Exercise}}$
# - Create [`DummyRegressor`](https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) instances for  `mean`, `median`. (e.g. `dummyinstance = DummyRegressor(strategy='mean')`)
# - Train them on the training data (`dummyinstance.fit(df_train[FEATURES], df_train[TARGET])`)

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for hints</font></summary>
# <ul>
#     <li> to create <code>DummyRegressor</code> you can for example use <code> dummyregressor_mean = DummyRegressor(strategy='mean') </code> </li>
#     <li> to see the implementation of the <code>DummyRegressor</code> you can check out <a href="https://github.com/scikit-learn/scikit-learn/blob/73732e5a0bc9b72c7049dc699d69aaedbb70ef0a/sklearn/dummy.py#L391"> the source code on GitHub</a> </li>
# </ul>
# </details>

# %%
# Build DummyRegressors
dummyregressor_mean = DummyRegressor(strategy='mean')
dummyregressor_median = DummyRegressor(strategy="median")

# %%
# Fit Dummy Regressors
dummyregressor_mean.fit(df_train_stratified[FEATURES], df_train_stratified[TARGET])
dummyregressor_median.fit(df_train_stratified[FEATURES], df_train_stratified[TARGET])
# Out:
# DummyRegressor(strategy='median')

# %% [markdown]
# #### Evaluate the performance of the dummy models

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - Calculate maximum error, mean absolute error and mean square error for the dummy regressors on training and test set. What would you expect those numbers to be? <br><br>
# We would expect high values. <br><br>
# - Do the actual values surprise you? <br><br>
# Not really, because these models do not take features (X) into account. They make a constant prediction (mean or median).Therefore, the errors are relatively high, especially if the true values are scattered. <br><br>
# - What does this mean in practice for reporting of metrics/the reasoning behind using baseline models?<br><br>
# DummyRegressors serve as baselines (starting points for comparison). We use baseline models because they help interpret metrics: a good score is only good if it is better than the baseline.
#
# It can be handy to store our metrics of choice in a nested dictionary ([Python dictionaries are key-value pairs](https://www.tutorialspoint.com/python/python_dictionary.htm)):
#
# ```python
# {
#     'dummyestimator1': {
#                         'metric_a_key': metric_a_value,
#                         'metric_b_key': metric_b_value
#                     },
#     'dummyestimator2': {
#                         'metric_a_key': metric_a_value,
#                         'metric_b_key': metric_b_value
#                     },
#  }
# ```
#
# You will now write functions `get_regression_metrics(model, X, y_true)` that compute the metrics and return this dictionary for a given model. The `predict` method takes the feature matrix $\mathbf{X}$ as input.
#
# In them, we calculate
#
# $\mathrm {MAE} =\frac{\sum _{i=1}^{n}\left|Y_{i}-\hat{y}_{i}\right|}{n}.$
#
# and
#
# $\mathrm {MSE} = {\frac {1}{n}}\sum _{i=1}^{n}(Y_{i}-{\hat {Y_{i}}})^{2}.$
#
# where $\hat{y}$ are the predictions and, $Y_{i}$ the true values.
#
# as well as the maximum error.

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for hints</font></summary>
# <ul>
#     <li> to perform a prediction using a estimator object, you can call <code> classifier.predict(X) </code> </li>
#     <li> to calculate metrics, you can for example call <code>accuracy_score(true_values, predicted_values) </code> </li>
# </ul>
# </details>

# %%
def get_regression_metrics(model, X, y_true):
    """
    Get a dicionary with regression metrics:

    model: sklearn model with predict method
    X: feature matrix
    y_true: ground truth labels
    """
    y_predicted = model.predict(X)

    mae = mean_absolute_error(y_true,y_predicted)
    mse = mean_squared_error(y_true,y_predicted)
    maximum_error = max_error(y_true,y_predicted)

    metrics_dict = {
        'mae': mae,
        'mse': mse,
        'max_error': maximum_error
    }

    return metrics_dict

# %%
dummy_regressors = [
    ('mean', dummyregressor_mean),
    ('median', dummyregressor_median)
]

# %%
dummy_regressor_results_test = {} # initialize empty dictionary
dummy_regressor_results_train = {}

# loop over the dummy_regressor list
# if you have a tuple regressorname, regressor = (a, b) that is automatically expanded into the variables
# a = regressorname, b = regressor
for regressorname, regressor in dummy_regressors:
    print(f"Calculating metrics for {regressorname}")
    dummy_regressor_results_test[regressorname] = get_regression_metrics(regressor, df_train_stratified[FEATURES], df_train_stratified[TARGET])
    dummy_regressor_results_train[regressorname] = get_regression_metrics(regressor,df_train_stratified[FEATURES], df_train_stratified[TARGET])
    

print(dummy_regressor_results_train)
# Out:
# DummyRegressor()
# Calculating metrics for mean
# DummyRegressor(strategy='median')
# Calculating metrics for median
# {'mean': {'mae': 6.332682697746153, 'mse': 54.36178484567787, 'max_error': 22.60380294886913}, 'median': {'mae': 6.260356674045894, 'mse': 56.25664180040652, 'max_error': 23.980340981299996}}

# %% [markdown]
# ## 5. Build actual regression models

# %% [markdown]
# Let's build a simple [kernel ridge regression (KRR)](https://emtiyaz.github.io/pcml15/kernel-ridge-regression.pdf) machine learning model and train it with our raw data.
# You can try different kernels, but we recommend to start with the Gaussian radial basis function ('rbf') kernel.
#
#  $\color{DarkBlue}{\textsf{Short Question}}$
# - Do you expect this model to perform better than the dummy models? <br><br>
# Yes because the dummy model make a constant prediction (mean or median).<br><br>
# - Train it and then calculate the performance metrics on the training and test set. How do they compare to the performance of the dummy models? <br><br>
# The value for the maximum error, mean absolute error and mean square error are all smaller than the one calculated for the dummy models, which means that this model is better than the dummy models. <br><br>
# - What is the shape of the Kernel and of the weights? (you can check your answer by looking at the `dual_coef_` attribute of the KRR instance. You can get shapes of objects using the `shape` atrribute. <br><br>
# The shape of the weights (krr.dual_coef_.shape) is (12165,) and the shape of the Kernel, which is a matrix is (12165, 12165)

# %%
# Train the model with a Gaussian kernel
krr = KernelRidge(kernel='rbf')
krr.fit(df_train_stratified[FEATURES], df_train_stratified[TARGET]) 
krr.dual_coef_.shape
krr._get_kernel(df_train_stratified[FEATURES]).shape
# Out:
# (12165, 12165)

# %%
# get the metrics on the train and the test set using the get_regression_metrics functions (as above)
train_metrics = get_regression_metrics(krr, df_train_stratified[FEATURES], df_train_stratified[TARGET])
test_metrics = get_regression_metrics(krr, df_test_stratified[FEATURES], df_test_stratified[TARGET])

print(f"Training metrics: {train_metrics}")
print(f"Test metrics: {test_metrics}")
# Out:
# Training metrics: {'mae': 5.8930721293080754, 'mse': 48.35125984203933, 'max_error': 17.207763399500003}
# Test metrics: {'mae': 11.692068235569346, 'mse': 189.94569670655383, 'max_error': 34.4921121426}

# %% [markdown]
# ## 6. Evaluate the model performance in detail

# %% [markdown]
# We have trained our first machine learning model!
# We'll first have a closer look at its performance, before learning how to improve it.

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - Create a parity plot (true values against predictions)for the training and test data
# - Plot a histogram of the distribution of the training and test errors on the training and test set. Plot the errors also as a function of the true value
# - Let's assume we would like to use our model for pre-screening a library of millions of porous materials to zoom-in on those with the most promising gas uptake. Could you tolerate the errors of your model?
# - Compare the parity plots for this model with the ones for the dummy models.
# Use the plotting functions below the evaluate all the following models you train.
#
# For this exercise, it can be handy to save the results in a dictionary, e.g.
# ```(python)
# res_train = {
#     'y true': [],
#     'y pred': []
# }
# ```

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for hints for plotting</font></summary>
# <ul>
#     <li> If you want to use matplotlib to make the parity plots, you can use the <a href="https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist2d.html">hist2d function</a> </li>
#     <li> To create the frequencies and the edges of a histogram, one can use <code>np.histogram</code></li>
# </ul>
# </details>

# %%
# Predict 
y_pred_train = krr.predict(df_train_stratified[FEATURES])
y_pred_test  = krr.predict(df_test_stratified[FEATURES])

# Create dictionaries with training and test results to create parity plots
res_train = {
    'y true': df_train_stratified[TARGET], 
    'y pred': y_pred_train 
}

res_test = {
    'y true': df_test_stratified[TARGET], 
    'y pred': y_pred_test 
}

# %% [markdown]
# Now, lets calculate the errors

# %%
res_train["error"] = res_train["y true"] - res_train["y pred"]
res_test["error"] = res_test["y true"] - res_test["y pred"]

# %% [markdown]
# Now, plot the parity plots and error distributions

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for hints for plotting</font></summary>
# If you want interactive plots, you can use the following code:
# <pre><code>
# hv.extension("bokeh")
# hex_train = hv.HexTiles(res_train, ["y true", "y pred"]).hist(
#     dimension=["y true", "y pred"]
# )
# hex_test = hv.HexTiles(res_test, ["y true", "y pred"]).hist(
#     dimension=["y true", "y pred"]
# )
# hex_train + hex_test
# </code>
# </details>

# %% [markdown]
# Parity plot showing all points for the train and test set.
#
# Are compared predicted and actual gas uptakes. The diagonal line y=x presents an ideal situation where the predictions exactly fit the actual values. The model is still accurate if the scatter is tight around the diagonal. However, the larger the deviation the more biased is the model thus the materials’ pre-screening.

# %%
y_true_train = res_train['y true']
y_pred_train = res_train['y pred']
y_true_test = res_test['y true']
y_pred_test = res_test['y pred']

# Common axis limits 
all_y = np.concatenate([y_true_train, y_true_test])
min_y, max_y = np.min(all_y), np.max(all_y)

# Train parity plot
plt.figure(figsize=(4,4))
plt.scatter(y_true_train, y_pred_train, color='blue', alpha=0.6)
plt.plot([min_y, max_y], [min_y, max_y], 'k--', lw=2)  # perfect parity line
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Parity Plot - Train")
plt.axis('equal')
plt.show()

# Test parity plot
plt.figure(figsize=(4,4))
plt.scatter(y_true_test, y_pred_test, color='red', alpha=0.6)
plt.plot([min_y, max_y], [min_y, max_y], 'k--', lw=2)  # perfect parity line
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Parity Plot - Test")
plt.axis('equal')
plt.show()

# %% [markdown]
# #### Parity plots

# %%
# plot it
hist_density(res_train['y true'].to_numpy(), res_train['y pred'])
# Out:
# <Axes: xlabel='Actual', ylabel='Predicted'>

# %%
hist_density(res_test['y true'].to_numpy(), res_test['y pred'])
# Out:
# <Axes: xlabel='Actual', ylabel='Predicted'>

# %% [markdown]
# #### Histogramm of errors
# For the model to be unbiased, histograms need to be centered around 0. The broader they are, the more uncertain is the error distribution thus the materials’ pre-screening.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Training errors
counts_train, bin_edges_train = np.histogram(res_train["error"], bins=40)
bin_centers_train = 0.5 * (bin_edges_train[:-1] + bin_edges_train[1:])
axes[0].bar(bin_centers_train, counts_train, width=(bin_edges_train[1]-bin_edges_train[0]), color='blue', alpha=0.6, edgecolor='black')
axes[0].set_title("Training Error Distribution")
axes[0].set_xlabel("Error")
axes[0].set_ylabel("Frequency")

# Test errors
counts_test, bin_edges_test = np.histogram(res_test["error"], bins=40)
bin_centers_test = 0.5 * (bin_edges_test[:-1] + bin_edges_test[1:])
axes[1].bar(bin_centers_test, counts_test, width=(bin_edges_test[1]-bin_edges_test[0]), color='red', alpha=0.6, edgecolor='black')
axes[1].set_title("Test Error Distribution")
axes[1].set_xlabel("Error")
axes[1].set_ylabel("Frequency")

plt.show()

# %% [markdown]
# #### Error as a function of  true value
# This plot enables to show if a correlation exists between errors and true values. In our context, that is ranking porous materials, a problem would occur if error values would increase with increasing true values because the latter are our target materials.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

#Train 
axes[0].scatter(res_train["y true"], res_train["error"], alpha=0.5, color="blue")
axes[0].set_title("Error vs True Value (Train)")
axes[0].set_xlabel("True Value")
axes[0].set_ylabel("Error")

#TEST
axes[1].scatter(res_test["y true"], res_test["error"], alpha=0.5, color="green")
axes[1].set_title("Error vs True Value (Test)")
axes[1].set_xlabel("True Value")
axes[1].set_ylabel("Error")

plt.show()

# %% [markdown]
# #### Evaluating the errors acceptance:
# According to the various graphs obtained, our model is not quite accurate and precise. The materials’ pre-screening is biased; it could exclude promising candidates due to underfitting or on the contrary include underperforming materials because of overfitting.  This conclusion requires improvement of the model!

# %%
#comparation with dummy model 
# Predict 
y_pred_train = dummyregressor_mean.predict(df_train_stratified[FEATURES])
y_pred_test  = dummyregressor_mean.predict(df_test_stratified[FEATURES])

# Create dictionaries with training and test results to create parity plots
res_train_dummy = {
    'y true': df_train_stratified[TARGET], 
    'y pred': y_pred_train 
}

res_test_dummy = {
    'y true': df_test_stratified[TARGET], 
    'y pred': y_pred_test 
}

# --- Common axis limits for consistency ---
all_y = np.concatenate([res_train_dummy ['y true'],res_test_dummy ['y true']])
min_y, max_y = np.min(all_y), np.max(all_y)

# --- Train parity plot ---
plt.figure(figsize=(3,3))
plt.scatter(res_train_dummy ['y true'], res_train_dummy['y pred'], color='blue', alpha=0.6)
plt.plot([min_y, max_y], [min_y, max_y], 'k--', lw=2)  # perfect parity line
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Parity Plot - Train Dummy ")
plt.axis('equal')
plt.show()

# --- Test parity plot ---
plt.figure(figsize=(3,3))
plt.scatter(res_test_dummy ['y true'], res_test_dummy['y pred'], color='red', alpha=0.6)
plt.plot([min_y, max_y], [min_y, max_y], 'k--', lw=2)  # perfect parity line
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Parity Plot - Test Dummy ")
plt.axis('equal')
plt.show()

# %% [markdown]
# The parity plot of the dummy model has a horizontal line for both the training and test set showing no correlation between the true values and predicted values. Therefore, the dummy model is not good. Our model works for the training set, having a correlation. But, the test set is not great because most of the points are at zero. So our model should be imporved.

# %% [markdown]
# ## 7. Improve the model

# %% [markdown]
# Our training set still has a couple of issues you might have noticed:
# - The feature values are not scaled (different features are measured in different units ...)
# - Some features are basically constant, i.e. do not contain relevant information and just increase the dimensionality of the problem
# - Some feature distributions are skewed (which is more relevant for some models than for others ...)

# %% [markdown]
# $\color{DarkBlue}{\textsf{Short Question}}$
# - Why might the scaling of the features be relevant for a machine learning model? <br>
#
# Feature scaling is important because many machine learning algorithms like Kernel Ridge are sensitive to the magnitudes of input variables.
# If features are measured in different units or ranges, those with larger numeric scales will dominate distance-based calculations on which Kernel Ridge is built.
# By scaling, we ensure that all features contribute equally so that the model is trained correctly.

# %% [markdown]
# ### 7.1. Standard scaling and building a first pipeline

# %% [markdown]
# Given that we will now go beyond training a single model, we will build [Pipelines](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html), which are objects that can collect a selection of transformations and estimators. This makes it quite easy to apply the same set of operations to different datasets. A simple pipeline might be built as follows
#
# <img src="https://vitalflux.com/wp-content/uploads/2020/08/ML-Pipeline-Page-2-1024x307.png" alt="Pipeline" width="800"/>

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - Build a pipline that first performs standard scaling and then fits a KRR. Call it `pipe_w_scaling`.
# - Fit it on the training set
# - Make predictions, calculate the errors and make the parity plots

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for hints</font></summary>
# <ul>
#     <li> the <code>fit</code>, <code>predict</code> methods also work for pipelines </li>
# </ul>
# </details>

# %%
# Pipline that performs standard scaling then fits a KRR
pipe_w_scaling = Pipeline(
   [
       ('scaling', StandardScaler()),
       ('krr', KernelRidge(kernel='rbf'))
   ]
)

# Fit it on the training set 
pipe_w_scaling.fit(df_train_stratified[FEATURES], df_train_stratified[TARGET])

# make predicitions 
y_pred_train = pipe_w_scaling.predict(df_train_stratified[FEATURES])
y_pred_test  = pipe_w_scaling.predict(df_test_stratified[FEATURES])

# dictionnary
res_train = {
    'y true': df_train_stratified[TARGET], 
    'y pred': y_pred_train 
}

res_test = {
    'y true': df_test_stratified[TARGET], 
    'y pred': y_pred_test 
}

# errors
res_train["error"] = res_train["y true"] - res_train["y pred"]
res_test["error"] = res_test["y true"] - res_test["y pred"]

# plot it
hist_density(res_train['y true'].to_numpy(), res_train['y pred'])
hist_density(res_test['y true'].to_numpy(), res_test['y pred'])
# Out:
# <Axes: xlabel='Actual', ylabel='Predicted'>

# %% [markdown]
# ### 7.2. Hyperparameter optimization

# %% [markdown]
# A key component we did not optimize so far are hyperparameters. Those are parameters of the model that we usually cannot learn from the data but have to fix before we train the model.
# Since we cannot learn those parameters it is not trivial to select them. Hence, what we typically do in practice is to create another set, a "validation set", and use it to test models trained with different hyperparameters.
#
# The most common approach to hyperparameter optimization is to define a grid of all relevant parameters and to search over the grid for the best model performance.

# %% [markdown]
# $\color{DarkBlue}{\textsf{Short Exercise}}$
# - Think about which parameters you could optimize in the pipeline. Note that your KRR model has two parameters you can optimize. You can also switch off some steps by setting them to `None'.
# - For each parameter you need to define a resonable grid to search over.
# - Recall, what k-fold cross-validation does. Run the hyperparameter optimization using 5-fold cross-validation (you can adjust the number of folds according to your computational resources/impatience. It turns out at k=10 is the [best tradeoff between variance and bias](https://arxiv.org/abs/1811.12808)).
# Tune the hyperparameters until you are statisfied (e.g., until you cannot improve the cross validated error any more)
# - Why don't we use the test set for hyperparameter tuning but instead test on the validation set?
# - Evaluate the model performance by calculating the performance metrics (MAE, MSE, max error) on the training and the test set.
# - *Optional:* Instead of grid search, try to use random search on the same grid (`RandomizedSearchCV`) and fix the number of evaluations (`n_iter`) to a fraction of the number of evaluations of grid search. What do you observe and conclude?

# %% [markdown]
# #### Answers to short exercise

# %% [markdown]
# - In our pipeline, we can optimize the Kernel Ridge Regression model hyperparameters: regularization strength α and RBF kernel width γ, which control smoothness and flexibility of the model.
#
# - Reasonable grids: <br>
# alpha = [1e-3, 1e-2, 1, 100] <br>
# gamma = [1e-2, 1e-1, 1, 10]
#
# - We don’t use the test set for hyperparameter tuning because it must remain completely unseen until the very end of the modeling process, when the final performance is measured.
# Using the test set for tuning would leak information about it into the model and the model would learn from the test indirectly. This would lead to performance bias.
# Instead, we tune hyperparameters on a validation set and use the test set only once to fairly assess the model’s generalization ability.

# %% [markdown]
#  $\color{DarkRed}{\textsf{Tips}}$
# - If you want to see what is happening, set the `verbosity` argument of the `GridSearchCV` object to a higher number.
#
# - If you want to speed up the optimization, you can run it in parallel by setting the `n_jobs` argument to the number of workers. If you set it to -1 it will use all available cores. *Using all cores might freeze your computer if you do not have enough memory*
#
# - If the optimization is too slow, reduce the number of data points in your set, the number of folds or the grid size. Note that it can also be a feasible strategy to first use a coarser grid and the a finer grid for fine-tuning.
#
# - For grid search, you need to define a parameter grid, which is a dictionary of the following form:
# ```(python)
# param_grid = {
#                     'pipelinestage__parameter': np.logspace(-4,1,10),
#                     'pipelinestage': [None, TransformerA(), TransformerB()]
#             }
# ```
#
# - After the search, you can access the best model with `.best_estimator_` and the best parameters with `.best_params_` on the GridSearchCV instance. For example `grid_krr.best_estimator_`
#
# - If you initialize the GridSearchCV instance with `refit=True` it will automatically train the model with all training data (and not only the training folds from cross-validations)
#
# The double underscore (dunder) notation works recursively and specifies the parameters for any pipeline stage.
# For example, `ovasvm__estimator__cls__C` would specifiy the `C` parameter of the estimator in the one-versus-rest classifier `ovasvm`.
#
# You can print all parameters of the pipeline using `print(sorted(pipeline.get_params().keys()))`

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Be aware that tight grids will drastically increase the number of experiments you will run! In some cases, it can be useful to perform the optimization in steps, i.e., first use a coarse grid and then refine in interesting regions.
# Alternatively, there are approached like <a href="https://www.jmlr.org/papers/volume18/16-558/16-558.pdf"> hyperband <a> that dynamically adjust the number of data points.
# </div>

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for hints about pipelines and grid search</font></summary>
# <ul>
#     <li> You can use the <code>np.logspace</code> function to generate a grid for values that you want to vary on a logarithmic scale </li>
#     <li> There are two hyperparameters for KRR: the regularization strength <code>alpha</code> and the Gaussian width  <code>gamma</code> </li>
#     <li> For the regularization strength, values between 1 and 1e-3 can be reasonable. For gamma you can use the median heuristic, gamma = 1 / median, or values between 1e-3 and 1e3</li>
# </ul>
# </details>

# %%
# Define the parameter grid and the grid search object
param_grid = {
                    'scaling': [MinMaxScaler(), StandardScaler()], # test different scaling methods
                    'krr__alpha': [1e-3, 1e-2, 1, 100],
                    'krr__gamma': [0.01, 0.1, 1, 10]
            }

grid_krr = GridSearchCV(pipe_w_scaling, param_grid,
                        cv=5, verbose=2, n_jobs=2)

# optional random search
#random_krr = RandomizedSearchCV(#your pipeline, param_distributions=param_grid, n_iter=#number of evaluations,
#                        cv=#number of folds, verbose=2, n_jobs=2)

# %%
# run the grid search by calling the fit method
grid_krr.fit(df_train_stratified[FEATURES], df_train_stratified[TARGET])
# optional random search
# random_krr.fit(#fillme)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   4.5s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   4.5s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   4.2s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   4.4s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   4.3s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(); total time=   4.3s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(); total time=   4.6s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(); total time=   4.9s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(); total time=   4.4s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(); total time=   4.6s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   4.7s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   4.7s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   4.7s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   4.9s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   4.8s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=StandardScaler(); total time=   4.9s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.0s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=StandardScaler(); total time=   4.8s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=StandardScaler(); total time=   4.8s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=StandardScaler(); total time=   4.6s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=MinMaxScaler(); total time=   4.7s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=MinMaxScaler(); total time=   4.9s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=MinMaxScaler(); total time=   4.6s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=MinMaxScaler(); total time=   4.8s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=MinMaxScaler(); total time=   4.9s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=StandardScaler(); total time=   4.8s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=StandardScaler(); total time=   4.9s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=StandardScaler(); total time=   5.0s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=StandardScaler(); total time=   5.0s
# [CV] END krr__alpha=0.001, krr__gamma=1, scaling=StandardScaler(); total time=   5.2s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.0s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.1s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.1s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.1s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=MinMaxScaler(); total time=   4.9s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(); total time=   5.1s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(); total time=   5.0s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(); total time=   4.8s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(); total time=   5.0s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(); total time=   5.1s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.2s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.3s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.3s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.0s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.1s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.2s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.5s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=0.01, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.7s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.0s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.0s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.3s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.6s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=StandardScaler(); total time=   5.6s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=StandardScaler(); total time=   5.2s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=StandardScaler(); total time=   5.2s
# [CV] END krr__alpha=0.01, krr__gamma=1, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.9s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=MinMaxScaler(); total time=   6.4s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.2s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.0s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(); total time=   5.8s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(); total time=   6.4s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(); total time=   6.3s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(); total time=   5.9s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(); total time=   5.7s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.2s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.1s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.2s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.3s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.3s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.8s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=StandardScaler(); total time=   6.0s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.3s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.2s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.2s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.3s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.1s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.5s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.1s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.2s
# [CV] END .krr__alpha=1, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.1s
# [CV] END .krr__alpha=1, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.2s
# [CV] END .krr__alpha=1, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.3s
# [CV] END .krr__alpha=1, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END .krr__alpha=1, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=StandardScaler(); total time=   5.5s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.6s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.1s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(); total time=   5.7s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(); total time=   5.9s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(); total time=   5.7s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(); total time=   5.6s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.3s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.7s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.3s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.6s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.6s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=StandardScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.9s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.8s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.6s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.7s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.7s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=0.1, scaling=StandardScaler(); total time=   5.6s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.6s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.7s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=MinMaxScaler(); total time=   5.4s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=StandardScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=StandardScaler(); total time=   5.4s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=StandardScaler(); total time=   5.5s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=StandardScaler(); total time=   5.6s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.7s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=MinMaxScaler(); total time=   6.0s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.9s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.8s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=MinMaxScaler(); total time=   5.8s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(); total time=   6.5s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(); total time=   6.7s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(); total time=   6.9s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(); total time=   6.9s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(); total time=   5.6s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaling', StandardScaler()),
#                                        ('krr', KernelRidge(kernel='rbf'))]),
#              n_jobs=2,
#              param_grid={'krr__alpha': [0.001, 0.01, 1, 100],
#                          'krr__gamma': [0.01, 0.1, 1, 10],
#                          'scaling': [MinMaxScaler(), StandardScaler()]},
#              verbose=2)

# %%
#best 
best_model = grid_krr.best_estimator_
best_para = grid_krr.best_params_

# %%
#EVALUATING THE MODEL
# get the performance metrics
train_metrics = get_regression_metrics(grid_krr,df_train_stratified[FEATURES], df_train_stratified[TARGET])
test_metrics = get_regression_metrics(grid_krr, df_test_stratified[FEATURES], df_test_stratified[TARGET])

print(f"Training metrics: {train_metrics}")
print(f"Test metrics: {test_metrics}")
# Out:
# Training metrics: {'mae': 0.6235301543475479, 'mse': 0.8393054326802295, 'max_error': 6.925115239352241}
# Test metrics: {'mae': 0.7141159802880948, 'mse': 1.15361658746815, 'max_error': 8.393321844653553}

# %% [markdown]
# The model is way better than at the beginning without scaling and hyperparameters, because all metric values are a lot smaller.

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for some more information about hyperparameter optimization</font></summary>
# Grid search is not the most efficient way to perform hyperparamter optimization. Even <a href="http://jmlr.csail.mit.edu/papers/volume13/bergstra12a/bergstra12a.pdf">random search was shown to be more efficient</a>. Really efficient though are Bayesian optimization approaches like <a href='https://papers.nips.cc/paper/4443-algorithms-for-hyper-parameter-optimization.pdf)'>TPE</a>. This is implemented in the hyperopt library, which is also installed in your conda environment.
# </details>

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for hyperparameter optimization with hyperopt (advanded and optional outlook)</font></summary>
#
# <b>Import the tools we need</b>
# <code>
# from hyperopt import fmin, tpe, hp, STATUS_OK, Trials, mix, rand, anneal, space_eval
# from functools import partial
# </code>
#
# <b>Define the grid</b>
# <code>
# param_hyperopt = {
#     "krr__alpha": hp.loguniform("krr__alpha", np.log(0.001), np.log(10)),
#     "krr__gamma": hp.loguniform("krr__gamma", np.log(0.001), np.log(10)),
# }
# </code>
#
# <b>Define the objective function</b>
# <code>
# def objective_function(params):
#     pipe.set_params(
#         **{
#             "krr__alpha": params["krr__alpha"],
#             "krr__gamma": params["krr__gamma"],
#         }
#     )
#     score = cross_val_score(
#         pipe, X_train, y_train, cv=10, scoring="neg_mean_absolute_error"
#     ).mean()
#     return {"loss": -score, "status": STATUS_OK}
# </code>
#
# <b>We will use a search in which we mix random search, annealing and tpe</b>
# <code>
# trials = Trials()
# mix_search = partial(
#    mix.suggest,
#    p_suggest=[(0.15, rand.suggest), (0.15, anneal.suggest), (0.7, tpe.suggest)],
# )
# </code>
#
# <b>Now, we can minimize the objective function.</b>
# <code>
# best_param = fmin(
#         objective_function,
#         param_hyperopt,
#         algo=mix_search,
#         max_evals=MAX_EVALES,
#         trials=trials,
#         rstate=np.random.RandomState(RANDOM_SEED),
#     )
# </code>
#
# </details>

# %% [markdown]
# ## 8. Feature Engineering

# %% [markdown]
# Finally, we would like to remove features with low variance. This can be done by setting a variance threshold.

# %% [markdown]
# $\color{DarkBlue}{\textsf{Short Question}}$
#
# - What is the reasoning behind doing this?
#
# Low variance features barely change across the dataset and remain constant for every sample. Removing them makes sense as they do not help the model distinguish samples, thus do not provide any useful information for prediction. By doing so, the computational cost is reduced, and the model is simplified without losing predictive power.
#
#
# - When might it go wrong and why?
#
# However, this approach can go wrong if a rare feature is highly predictive (that is with low variance except for a few informative cases) or if the variance threshold is set too high. Both would cause the removal of informative features.

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - Add a variance threshold to the pipeline (select the correct function argument)
# - Use random search for hyperparameter optimization, retrain the pipeline, and calculate the performance metrics (max error, MAE, MSE) on the training and test set

# %%
# Define the pipeline
pipe_variance_threshold = Pipeline(   
    [
        ('variance_treshold', VarianceThreshold(0.01)),
        ('scaling', StandardScaler()), 
        ('krr', KernelRidge( kernel='rbf'))
    ]
)

# %%
param_grid_variance_threshold = {
                    'scaling': [None, StandardScaler()],
                    'krr__alpha': [1e-3, 1e-2, 1, 100],
                    'krr__gamma': [0.01, 0.1, 1, 10],
                    'variance_treshold__threshold': [0.0, 0.001, 0.01, 0.05]
            }

random_variance_treshold = RandomizedSearchCV(pipe_variance_threshold, param_distributions=param_grid_variance_threshold, n_iter= 20,
                        cv= 5, verbose=2, n_jobs=2)

# %%
# Fit the pipeline and run the evaluation
random_variance_treshold.fit(df_train_stratified[FEATURES], df_train_stratified[TARGET])

# get the performance metrics
train_metrics = get_regression_metrics(random_variance_treshold,df_train_stratified[FEATURES], df_train_stratified[TARGET])
test_metrics = get_regression_metrics(random_variance_treshold, df_test_stratified[FEATURES], df_test_stratified[TARGET])

print(f"Training metrics: {train_metrics}")
print(f"Test metrics: {test_metrics}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.05; total time=   6.5s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.05; total time=   6.7s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.05; total time=   6.3s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.05; total time=   6.5s
# [CV] END krr__alpha=0.001, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.05; total time=   6.3s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.8s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.4s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.5s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.6s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.7s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   5.6s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   5.8s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   6.0s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   5.8s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   5.4s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=None, variance_treshold__threshold=0.01; total time=   5.4s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=None, variance_treshold__threshold=0.01; total time=   5.6s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=None, variance_treshold__threshold=0.01; total time=   5.8s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=None, variance_treshold__threshold=0.01; total time=   6.2s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=None, variance_treshold__threshold=0.01; total time=   6.3s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.05; total time=   6.0s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.05; total time=   5.9s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.05; total time=   5.8s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.05; total time=   6.0s
# [CV] END krr__alpha=100, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.05; total time=   6.0s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=None, variance_treshold__threshold=0.001; total time=   5.9s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=None, variance_treshold__threshold=0.001; total time=   5.7s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=None, variance_treshold__threshold=0.001; total time=   5.9s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=None, variance_treshold__threshold=0.001; total time=   6.4s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=None, variance_treshold__threshold=0.001; total time=   6.5s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.001; total time=   5.6s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.001; total time=   5.5s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.001; total time=   5.5s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.001; total time=   5.6s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.001; total time=   5.7s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=None, variance_treshold__threshold=0.05; total time=   5.6s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=None, variance_treshold__threshold=0.05; total time=   5.6s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=None, variance_treshold__threshold=0.05; total time=   5.6s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=None, variance_treshold__threshold=0.05; total time=   5.6s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=None, variance_treshold__threshold=0.05; total time=   5.7s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.0; total time=   5.7s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.0; total time=   5.7s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.0; total time=   5.9s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.0; total time=   5.8s
# [CV] END krr__alpha=1, krr__gamma=0.01, scaling=None, variance_treshold__threshold=0.0; total time=   5.9s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   5.9s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   5.7s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   5.8s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   6.0s
# [CV] END krr__alpha=1, krr__gamma=0.1, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   5.9s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   5.9s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   5.8s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   5.5s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   5.7s
# [CV] END krr__alpha=0.01, krr__gamma=0.1, scaling=None, variance_treshold__threshold=0.001; total time=   5.6s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.1s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.3s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.8s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.3s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.6s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=None, variance_treshold__threshold=0.0; total time=   6.0s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=None, variance_treshold__threshold=0.0; total time=   6.6s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=None, variance_treshold__threshold=0.0; total time=   6.1s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=None, variance_treshold__threshold=0.0; total time=   6.2s
# [CV] END krr__alpha=100, krr__gamma=1, scaling=None, variance_treshold__threshold=0.0; total time=   5.9s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.1s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.3s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.1s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.3s
# [CV] END krr__alpha=0.001, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.01; total time=   6.8s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   6.7s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   7.2s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   6.6s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   6.3s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   6.4s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   6.6s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   6.6s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   6.0s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   6.0s
# [CV] END krr__alpha=0.001, krr__gamma=0.01, scaling=StandardScaler(), variance_treshold__threshold=0.0; total time=   5.8s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   6.0s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   5.9s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   5.9s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   6.1s
# [CV] END krr__alpha=0.01, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.001; total time=   6.4s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   6.5s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   6.3s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   6.3s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   6.4s
# [CV] END krr__alpha=1, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   6.5s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=None, variance_treshold__threshold=0.01; total time=   5.9s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=None, variance_treshold__threshold=0.01; total time=   6.0s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=None, variance_treshold__threshold=0.01; total time=   6.0s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=None, variance_treshold__threshold=0.01; total time=   5.8s
# [CV] END krr__alpha=1, krr__gamma=1, scaling=None, variance_treshold__threshold=0.01; total time=   5.7s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   6.1s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   6.1s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   6.1s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   6.0s
# [CV] END krr__alpha=100, krr__gamma=10, scaling=StandardScaler(), variance_treshold__threshold=0.05; total time=   4.9s
# Training metrics: {'mae': 0.3103402503451012, 'mse': 0.24114659983391187, 'max_error': 5.084135920534607}
# Test metrics: {'mae': 0.7999104954092648, 'mse': 2.2205613681206784, 'max_error': 20.705810971852507}

# %% [markdown]
# $\color{DarkBlue}{\textsf{Short Exercise (optional)}}$
# - replace the variance threshold with a model-based feature selection
# `('feature_selection', SelectFromModel(LinearSVC(penalty="l1")))` or [any feature selection method that you would like to try](https://scikit-learn.org/stable/modules/feature_selection.html)

# %% [markdown]
# ## 9. Saving the model

# %% [markdown]
# Now, that we spent so much time in optimizing our model, we do not want to loose it.

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - use the [joblib library](https://scikit-learn.org/stable/modules/model_persistence.html) to save your model
# - make sure you can load it again

# %%
# Dump your model
filename = "model_random_variance_treshold.pkl"
joblib.dump(random_variance_treshold, filename)
# Out:
# ['model_random_variance_treshold.pkl']

# %%
# Try to load it again
model_loaded = joblib.load(filename)

# %% [markdown]
# ## 10. Influence of Regularization

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - what happens if you set $\alpha$  to a really small or to large value? Why is this the case explain what the parameter means using the equation derived in the lectures?
#
#  To test this, fix this value in one of your pipelines, retrain the models (re-optimizing the other hyperparameters) and rerun the performance evaluation.

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for hints</font></summary>
# <ul>
#     <li> Check the derivation for ridge regression and KRR in the notes. </li>
#     <li> Also remember the loss landscapes we discussed in the lectures about LASSO. </li>
# </ul>
# </details>

# %% [markdown]
# ## 11. Interpreting the model

# %% [markdown]
# Now, that our model performs decently, we would like to know which features are mainly responsible for this, i.e. how the model performs its reasoning.
#
# One method to do so is the [permutation feature importance technique](https://christophm.github.io/interpretable-ml-book/feature-importance.html).

# %% [markdown]
# $\color{DarkBlue}{\textsf{Short question}}$
#
# We use both descriptors that encode the pore geometry (density, pore diameters, surface areas) as well as some that describe the chemistry of the MOF (the RACs).
# - Would you expect the relative importance of these features to be different for prediction of gas adsorption at high vs low gas pressure?

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for a hint</font></summary>
# <ul>
#     <li> <a href="https://pubs.acs.org/doi/abs/10.1021/acs.chemmater.8b02257">An article from Diego et al.</a> (10.1021/acs.chemmater.8b02257) gives some hints.</li>
# </ul>
# </details>

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - Complete the function `_calculate_permutation_scores` (which we took from the `sklearn` package) and which is needed to calculate the permutation feature importance using the `permutation_importance` function.

# %%
def _calculate_permutation_scores(estimator, X, y, col_idx, random_state,
                                  n_repeats, scorer):
    """Calculate score when `col_idx` is permuted. Based on the sklearn implementation

    estimator: sklearn estimator object
    X: pd.Dataframe or np.array
    y: pd.Dataframe or np.array
    col_idx: int
    random_state: int
    n_repeats: int
    scorer: function that takes model, X and y_true as arguments
    """
    random_state = check_random_state(random_state)

    X_permuted = X.copy()
    scores = np.zeros(n_repeats)
    # get the indices
    shuffling_idx = np.arange(X.shape[0])
    for n_round in range(n_repeats):
        # FILL BELOW HERE
        # shuffle them (fill in what you want to shuffle)
        random_state.shuffle(#fillme)

        # Deal with dataframes
        if hasattr(X_permuted, "iloc"):
            # .iloc selects the indices from a dataframe and you give it [row, column]
            col = X_permuted.iloc[shuffling_idx, col_idx]
            col.index = X_permuted.index
            X_permuted.iloc[:, col_idx] = col

        # Deal with numpy arrays
        else:
            # FILL BELOW HERE
            # array indexing is [row, column]
            X_permuted[:, col_idx] = X_permuted[#fillme]

        # Get the scores
        feature_score = scorer(estimator, X_permuted, y)

        # record the scores in array
        scores[n_round] = feature_score

    return scores

# %% [markdown]
# Nothing to change in the function below, it just call the `_calculate_permutation_scores` function you just completed.

# %%
def permutation_importance(
    estimator,
    X,
    y,
    scoring="neg_mean_absolute_error",
    n_repeats=5,
    n_jobs=2,
    random_state=None,
):
    """Permutation importance for feature evaluation
    estimator : object
        An estimator that has already been :term:`fitted` and is compatible
        with :term:`scorer`.
    X : ndarray or DataFrame, shape (n_samples, n_features)
        Data on which permutation importance will be computed.
    y : array-like or None, shape (n_samples, ) or (n_samples, n_classes)
        Targets for supervised or `None` for unsupervised.
    scoring : string, callable or None, default=None
        Scorer to use. It can be a single
        string (see :ref:`scoring_parameter`) or a callable (see
        :ref:`scoring`). If None, the estimator's default scorer is used.
    n_repeats : int, default=5
        Number of times to permute a feature.
    n_jobs : int or None, default=2
        The number of jobs to use for the computation.
        `None` means 1 unless in a :obj:`joblib.parallel_backend` context.
        `-1` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.
    random_state : int, RandomState instance, or None, default=None
        Pseudo-random number generator to control the permutations of each
        feature. See :term:`random_state`.
    """
    # Deal with dataframes
    if not hasattr(X, "iloc"):
        X = check_array(X, force_all_finite="allow-nan", dtype=None)

    # Precompute random seed from the random state to be used
    # to get a fresh independent RandomState instance for each
    # parallel call to _calculate_permutation_scores, irrespective of
    # the fact that variables are shared or not depending on the active
    # joblib backend (sequential, thread-based or process-based).
    random_state = check_random_state(random_state)
    random_seed = random_state.randint(np.iinfo(np.int32).max + 1)

    # Determine scorer from user options.
    scorer = check_scoring(estimator, scoring=scoring)
    # get the performance score on the unpermuted data
    baseline_score = scorer(estimator, X, y)

    # run the permuted evaluations in parallel for each column
    scores = Parallel(n_jobs=n_jobs)(
        delayed(_calculate_permutation_scores)(
            estimator, X, y, col_idx, random_seed, n_repeats, scorer
        )
        for col_idx in range(X.shape[1])
    )

    # get difference two
    importances = baseline_score - np.array(scores)

    # return the results (dictionary)
    return Bunch(
        importances_mean=np.mean(importances, axis=1),
        importances_std=np.std(importances, axis=1),
        importances=importances,
    )

# %% [markdown]
#  $\color{DarkBlue}{\textsf{Short Exercise}}$
# - Use your function to find the five most important features.
# - Which are they? Did you expect this result?

# %%
permutation_results = permutation_importance(#fillme)

# %%
permutation_results["features"] = FEATURES
bars = hv.Bars(
    permutation_results, "features", ["importances_mean", "importances_std"]
).sort("importances_mean", reverse=True)
errors = hv.ErrorBars(
    permutation_results, "features", vdims=["importances_mean", "importances_std"]
).sort("importances_mean", reverse=True)

bars * errors

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for hints</font></summary>
# <ul>
#     <li> To get the top <emph>n</emph> indices of an array <code>a</code>, you can use <code>np.argsort(a)[-n:]</code></li>
#     <li> Get the feature names from the <code>FEATURES</code> list </li>
#     <li> combined this might look like <code>np.array(FEATURES)[np.argsort(a)[-n:]]</code></li>
# </ul>
# </details>

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for more information on model interpretation</font></summary>
# The permutation feature importance technique is not a silver bullet, e.g. there are issues with correlated features.
# However, it is likely <a href='https://explained.ai/rf-importance/'>a better choice than feature importance, like impurity decrease, derived from random forests</a>).
# </details>
